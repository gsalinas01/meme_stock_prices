# %%
import time
import datetime
import pandas as pd

# %%
#define function to get stock hist data from today to last year

def getstockhist(ticker):
    #set an automated date for today
    today = datetime.date.today()
    year=2000+int(today.strftime("%y"))
    month=int(today.strftime("%m"))
    day=int(today.strftime("%d"))
    
    #set variable for 1 years ago, for start date
    year_start=2000+int(today.strftime("%y"))-1

    #period 1 is the oldest date, period 2 is the newest date
    period1=int(time.mktime(datetime.datetime(year_start,month,day,1,1).timetuple()))
    period2=int(time.mktime(datetime.datetime(year,month,day,1,1).timetuple()))
    # interval is per day 
    interval="1d"
    query_url=f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'
    df=pd.read_csv(query_url)
    df["Percent_Day_Change"]= ((df["Close"]/df["Open"])-1)*100
    # Create the output file (CSV).
    output_data_file = f'resources/{ticker}_stock_hist.csv'
    # Export the City_Data into a CSV.
    df.to_csv(output_data_file)
    return df

# %%
TSLA_hist_df=getstockhist("TSLA")
TSLA_hist_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-11-03   409.730011   427.769989   406.690002   423.899994
# 1    2020-11-04   430.619995   435.399994   417.100006   420.980011
# 2    2020-11-05   428.299988   440.000000   424.000000   438.089996
# 3    2020-11-06   436.100006   436.570007   424.279999   429.950012
# 4    2020-11-09   439.500000   452.500000   421.000000   421.260010
# ..          ...          ...          ...          ...          ...
# 247  2021-10-27  1039.660034  1070.880005  1030.780029  1037.859985
# 248  2021-10-28  1068.310059  1081.000000  1054.199951  1077.040039
# 249  2021-10-29  1081.859985  1115.209961  1073.209961  1114.000000
# 250  2021-11-01  1145.000000  1209.750000  1118.660034  1208.589966
# 251  2021-11-02  1159.359985  1208.589966  1146.000000  1172.000000
#
#        Adj Close    Volume  Percent_Day_Change
# 0     423.899994  34351700            3.458371
# 1     420.980011  32143100           -2.238629
# 2     438.089996  28414500            2.285783
# 3     429.950012  21706000           -1.410226
# 4     421.260010  34833000           -4.150168
# ..           ...       ...                 ...
# 247  1037.859985  38526500           -0.173138
# 248  1077.040039  27213200            0.817177
# 249  1114.000000  29918400            2.970811
# 250  1208.589966  56048700            5.553709
# 251  1172.000000  42737800            1.090258
#
# [252 rows x 8 columns]

# %%
spy_hist_df=getstockhist("SPY")
spy_hist_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-11-03  333.690002  338.250000  330.290009  336.029999  331.362274
# 1    2020-11-04  340.859985  347.940002  339.589996  343.540009  338.767914
# 2    2020-11-05  349.239990  352.190002  348.859985  350.239990  345.374817
# 3    2020-11-06  349.929993  351.510010  347.649994  350.160004  345.295959
# 4    2020-11-09  363.970001  364.380005  354.059998  354.559998  349.634827
# ..          ...         ...         ...         ...         ...         ...
# 247  2021-10-27  456.450012  457.160004  453.859985  453.940002  453.940002
# 248  2021-10-28  455.459991  458.399994  455.450012  458.320007  458.320007
# 249  2021-10-29  455.869995  459.559998  455.559998  459.250000  459.250000
# 250  2021-11-01  460.299988  460.700012  458.200012  460.040009  460.040009
# 251  2021-11-02  460.220001  462.230011  460.079987  461.899994  461.899994
#
#         Volume  Percent_Day_Change
# 0     93294200            0.701249
# 1    126959700            0.786254
# 2     82039700            0.286336
# 3     74973000            0.065731
# 4    172304200           -2.585379
# ..         ...                 ...
# 247   72438000           -0.549898
# 248   51437900            0.627940
# 249   70108200            0.741441
# 250   48433600           -0.056480
# 251   48908400            0.365041
#
# [252 rows x 8 columns]
