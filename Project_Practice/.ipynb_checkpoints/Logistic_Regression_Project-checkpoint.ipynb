# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
#Load data
SPY_stock_hist_hourly_2021_11_7_df = pd.read_csv(Path('Resources/SPY_stock_hist_hourly_2021_11_7.csv'))
SPY_stock_hist_hourly_2021_11_7_df.head()
# Out:
#                   Unnamed: 0        Open        High         Low       Close  \
# 0  2021-10-28 09:30:00-04:00  455.899994  457.125000  455.680115  457.059998
# 1  2021-10-28 10:30:00-04:00  457.070007  457.976013  457.000000  457.519989
# 2  2021-10-28 11:30:00-04:00  457.529999  457.950012  456.859985  457.299988
# 3  2021-10-28 12:30:00-04:00  457.304993  457.429993  456.500000  457.049988
# 4  2021-10-28 13:30:00-04:00  457.059998  457.869995  457.052490  457.779999
#
#     Adj Close   Volume  Percent_Day_Change          date_UTC
# 0  457.059998  9880982            0.254443  2021-10-28 05:00
# 1  457.519989  5874814            0.098449  2021-10-28 06:00
# 2  457.299988  4100046           -0.050272  2021-10-28 07:00
# 3  457.049988  3684041           -0.055763  2021-10-28 08:00
# 4  457.779999  7065893            0.157529  2021-10-28 09:00

# %%
#Load data
TSLA_tweet_7days_prior_hist_2021_11_7_perhour_df = pd.read_csv(Path('Resources/#TSLA_tweet_7days_prior_hist_2021_11_7_perhour.csv'))
TSLA_tweet_7days_prior_hist_2021_11_7_perhour_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  tweet_counts             date_UTC
# 0           0             0            22  2021-10-31 18:00:00
# 1           1             1            30  2021-10-31 19:00:00
# 2           2             2            16  2021-10-31 20:00:00
# 3           3             3            34  2021-10-31 21:00:00
# 4           4             4            93  2021-10-31 22:00:00

# %%
#Load data
TSLA_stock_hist_hourly_2021_11_7_df = pd.read_csv(Path('Resources/TSLA_stock_hist_hourly_2021_11_7.csv'))
TSLA_stock_hist_hourly_2021_11_7_df.head()
# Out:
#                   Unnamed: 0         Open         High          Low  \
# 0  2021-10-28 09:30:00-04:00  1068.305054  1081.000000  1055.209961
# 1  2021-10-28 10:30:00-04:00  1060.180054  1077.464966  1058.890015
# 2  2021-10-28 11:30:00-04:00  1070.839844  1079.689941  1064.349976
# 3  2021-10-28 12:30:00-04:00  1076.949951  1079.649902  1066.000000
# 4  2021-10-28 13:30:00-04:00  1073.250000  1074.030029  1067.589966
#
#          Close    Adj Close   Volume  Percent_Day_Change          date_UTC
# 0  1060.359985  1060.359985  8788599           -0.743708  2021-10-28 05:00
# 1  1070.250732  1070.250732  4857422            0.949903  2021-10-28 06:00
# 2  1076.380005  1076.380005  3591916            0.517366  2021-10-28 07:00
# 3  1073.175049  1073.175049  3328912           -0.350518  2021-10-28 08:00
# 4  1072.910034  1072.910034  1543551           -0.031676  2021-10-28 09:00

# %%
# Determine if there are any missing values in the school data.
SPY_stock_hist_hourly_2021_11_7_df.count()
# Out:
# Unnamed: 0            49
# Open                  49
# High                  49
# Low                   49
# Close                 49
# Adj Close             49
# Volume                49
# Percent_Day_Change    49
# date_UTC              49
# dtype: int64

# %%
# Determine if there are any missing values in the school data.
TSLA_stock_hist_hourly_2021_11_7_df.count()
# Out:
# Unnamed: 0            49
# Open                  49
# High                  49
# Low                   49
# Close                 49
# Adj Close             49
# Volume                49
# Percent_Day_Change    49
# date_UTC              49
# dtype: int64

# %%
# Determine if there are any missing values in the school data.
TSLA_tweet_7days_prior_hist_2021_11_7_perhour_df.count()
# Out:
# Unnamed: 0      169
# Unnamed: 0.1    169
# tweet_counts    169
# date_UTC        169
# dtype: int64

# %%
# Determine if there are any missing values in the school data.
SPY_stock_hist_hourly_2021_11_7_df.isnull()
# Out:
#     Unnamed: 0   Open   High    Low  Close  Adj Close  Volume  \
# 0        False  False  False  False  False      False   False
# 1        False  False  False  False  False      False   False
# 2        False  False  False  False  False      False   False
# 3        False  False  False  False  False      False   False
# 4        False  False  False  False  False      False   False
# 5        False  False  False  False  False      False   False
# 6        False  False  False  False  False      False   False
# 7        False  False  False  False  False      False   False
# 8        False  False  False  False  False      False   False
# 9        False  False  False  False  False      False   False
# 10       False  False  False  False  False      False   False
# 11       False  False  False  False  False      False   False
# 12       False  False  False  False  False      False   False
# 13       False  False  False  False  False      False   False
# ...

# %%
TSLA_stock_hist_hourly_2021_11_7_df.isnull()
# Out:
#     Unnamed: 0   Open   High    Low  Close  Adj Close  Volume  \
# 0        False  False  False  False  False      False   False
# 1        False  False  False  False  False      False   False
# 2        False  False  False  False  False      False   False
# 3        False  False  False  False  False      False   False
# 4        False  False  False  False  False      False   False
# 5        False  False  False  False  False      False   False
# 6        False  False  False  False  False      False   False
# 7        False  False  False  False  False      False   False
# 8        False  False  False  False  False      False   False
# 9        False  False  False  False  False      False   False
# 10       False  False  False  False  False      False   False
# 11       False  False  False  False  False      False   False
# 12       False  False  False  False  False      False   False
# 13       False  False  False  False  False      False   False
# ...

# %%
TSLA_tweet_7days_prior_hist_2021_11_7_perhour_df.isnull()
# Out:
#      Unnamed: 0  Unnamed: 0.1  tweet_counts  date_UTC
# 0         False         False         False     False
# 1         False         False         False     False
# 2         False         False         False     False
# 3         False         False         False     False
# 4         False         False         False     False
# ..          ...           ...           ...       ...
# 164       False         False         False     False
# 165       False         False         False     False
# 166       False         False         False     False
# 167       False         False         False     False
# 168       False         False         False     False
#
# [169 rows x 4 columns]

# %%
SPY_stock_hist_hourly_2021_11_7_df.isnull().sum()
# Out:
# Unnamed: 0            0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
# Volume                0
# Percent_Day_Change    0
# date_UTC              0
# dtype: int64

# %%
TSLA_tweet_7days_prior_hist_2021_11_7_perhour_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# tweet_counts    0
# date_UTC        0
# dtype: int64

# %%
TSLA_stock_hist_hourly_2021_11_7_df.isnull().sum()
# Out:
# Unnamed: 0            0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
# Volume                0
# Percent_Day_Change    0
# date_UTC              0
# dtype: int64

# %%
# Determine the school type.
tweet_counts = TSLA_tweet_7days_prior_hist_2021_11_7_perhour_df.set_index(["date_UTC"])["tweet_counts"]
tweet_counts
# Out:
# date_UTC
# 2021-10-31 18:00:00    22
# 2021-10-31 19:00:00    30
# 2021-10-31 20:00:00    16
# 2021-10-31 21:00:00    34
# 2021-10-31 22:00:00    93
#                        ..
# 2021-11-07 14:00:00    30
# 2021-11-07 15:00:00    57
# 2021-11-07 16:00:00    36
# 2021-11-07 17:00:00    27
# 2021-11-07 17:00:00     1
# Name: tweet_counts, Length: 169, dtype: int64

# %%
tsla_percent = TSLA_stock_hist_hourly_2021_11_7_df.set_index(["date_UTC"])["Percent_Day_Change"]
tsla_percent
# Out:
# date_UTC
# 2021-10-28 05:00   -0.743708
# 2021-10-28 06:00    0.949903
# 2021-10-28 07:00    0.517366
# 2021-10-28 08:00   -0.350518
# 2021-10-28 09:00   -0.031676
# 2021-10-28 10:00   -0.264277
# 2021-10-28 11:00    0.685840
# 2021-10-29 07:00            0.237971
# 2021-10-29 08:00           -0.063163
# 2021-10-29 09:00           -0.224469
# 2021-10-29 10:00            0.016384
# 2021-10-29 11:00            0.288274
# 2021-11-01 05:00           -0.247726
# 2021-11-01 06:00            0.043573
# 2021-11-01 07:00            0.096896
# 2021-11-01 08:00           -0.093542
# 2021-11-01 09:00           -0.137178
# 2021-11-01 10:00            0.170086
# 2021-11-01 11:00            0.154558
# 2021-11-02 05:00            0.217287
# 2021-11-02 06:00            0.123587
# 2021-11-02 07:00           -0.011910
# ...

# %%
tsla_percent_df = pd.DataFrame(tsla_percent)
tsla_percent_df
# Out:
#                   Percent_Day_Change
# date_UTC
# 2021-10-28 05:00           -0.743708
# 2021-10-28 06:00            0.949903
# 2021-10-28 07:00            0.517366
# 2021-10-28 08:00           -0.350518
# 2021-10-28 09:00           -0.031676
# 2021-10-28 10:00           -0.264277
# 2021-10-28 11:00            0.685840
# 2021-10-29 05:00            0.776865
# 2021-10-29 06:00            0.241562
# 2021-10-29 07:00            0.091629
# 2021-10-29 08:00            0.875232
# 2021-10-29 09:00           -0.469449
# 2021-10-29 10:00            0.354217
# 2021-10-29 11:00            1.240314
# 2021-11-01 05:00           -0.841486
# 2021-11-01 06:00            2.296756
# 2021-11-01 07:00            0.757828
# 2021-11-01 08:00            0.190653
# 2021-11-01 09:00           -0.455473
# 2021-11-01 10:00            2.059181
# 2021-11-01 11:00            1.550806
# 2021-11-02 05:00            3.952108
# 2021-11-02 06:00           -2.082436
# 2021-11-02 07:00           -1.228813
# ...

# %%
# Combine the data into a single dataset.
#dual_percent_df = pd.merge(spy_percent_df, tsla_percent_df, on=["date_UTC", "date_UTC"])
#dual_percent_df.head(5)

# %%
tweet_counts_df = tweet_counts_df.dropna()

# %%
tsla_percent_df = tsla_percent_df.dropna()

# %%
spy_percent_df = spy_percent_df.dropna()

# %%
dual_percent_df = pd.merge(spy_percent_df, tsla_percent_df, on= ["date_UTC"])
dual_percent_df.head(10)
# Out:
#                   Percent_Day_Change_x  Percent_Day_Change_y
# date_UTC
# 2021-10-28 05:00              0.254443             -0.743708
# 2021-10-28 06:00              0.098449              0.949903
# 2021-10-28 07:00             -0.050272              0.517366
# 2021-10-28 08:00             -0.055763             -0.350518
# 2021-10-28 09:00              0.157529             -0.031676
# 2021-10-28 10:00             -0.117962             -0.264277
# 2021-10-28 11:00              0.225269              0.685840
# 2021-10-29 05:00              0.190843              0.776865
# 2021-10-29 06:00              0.282420              0.241562
# 2021-10-29 07:00              0.237971              0.091629

# %%
dual_percent_df.append(tweet_counts_df)
# Out:
#                      Percent_Day_Change_x  Percent_Day_Change_y  tweet_counts
# date_UTC
# 2021-10-28 05:00                 0.254443             -0.743708           NaN
# 2021-10-28 06:00                 0.098449              0.949903           NaN
# 2021-10-28 07:00                -0.050272              0.517366           NaN
# 2021-10-28 08:00                -0.055763             -0.350518           NaN
# 2021-10-28 09:00                 0.157529             -0.031676           NaN
# ...                                   ...                   ...           ...
# 2021-11-07 14:00:00                   NaN                   NaN          30.0
# 2021-11-07 15:00:00                   NaN                   NaN          57.0
# 2021-11-07 16:00:00                   NaN                   NaN          36.0
# 2021-11-07 17:00:00                   NaN                   NaN          27.0
# 2021-11-07 17:00:00                   NaN                   NaN           1.0
#
# [218 rows x 3 columns]

# %%
all_df = dual_percent_df.append(tweet_counts_df)
all_df
# Out:
#                      Percent_Day_Change_x  Percent_Day_Change_y  tweet_counts
# date_UTC
# 2021-10-28 05:00                 0.254443             -0.743708           NaN
# 2021-10-28 06:00                 0.098449              0.949903           NaN
# 2021-10-28 07:00                -0.050272              0.517366           NaN
# 2021-10-28 08:00                -0.055763             -0.350518           NaN
# 2021-10-28 09:00                 0.157529             -0.031676           NaN
# ...                                   ...                   ...           ...
# 2021-11-07 14:00:00                   NaN                   NaN          30.0
# 2021-11-07 15:00:00                   NaN                   NaN          57.0
# 2021-11-07 16:00:00                   NaN                   NaN          36.0
# 2021-11-07 17:00:00                   NaN                   NaN          27.0
# 2021-11-07 17:00:00                   NaN                   NaN           1.0
#
# [218 rows x 3 columns]

# %%
all_df.dropna(subset=['tweet_counts'])
# Out:
#                      Percent_Day_Change_x  Percent_Day_Change_y  tweet_counts
# date_UTC
# 2021-10-31 18:00:00                   NaN                   NaN          22.0
# 2021-10-31 19:00:00                   NaN                   NaN          30.0
# 2021-10-31 20:00:00                   NaN                   NaN          16.0
# 2021-10-31 21:00:00                   NaN                   NaN          34.0
# 2021-10-31 22:00:00                   NaN                   NaN          93.0
# ...                                   ...                   ...           ...
# 2021-11-07 14:00:00                   NaN                   NaN          30.0
# 2021-11-07 15:00:00                   NaN                   NaN          57.0
# 2021-11-07 16:00:00                   NaN                   NaN          36.0
# 2021-11-07 17:00:00                   NaN                   NaN          27.0
# 2021-11-07 17:00:00                   NaN                   NaN           1.0
#
# [169 rows x 3 columns]

# %%
all_df.dropna(subset=['Percent_Day_Change_y'])
# Out:
#                   Percent_Day_Change_x  Percent_Day_Change_y  tweet_counts
# date_UTC
# 2021-10-28 05:00              0.254443             -0.743708           NaN
# 2021-10-28 06:00              0.098449              0.949903           NaN
# 2021-10-28 07:00             -0.050272              0.517366           NaN
# 2021-10-28 08:00             -0.055763             -0.350518           NaN
# 2021-10-28 09:00              0.157529             -0.031676           NaN
# 2021-10-28 10:00             -0.117962             -0.264277           NaN
# 2021-10-28 11:00              0.225269              0.685840           NaN
# 2021-10-29 05:00              0.190843              0.776865           NaN
# 2021-10-29 06:00              0.282420              0.241562           NaN
# 2021-10-29 07:00              0.237971              0.091629           NaN
# 2021-10-29 08:00             -0.063163              0.875232           NaN
# ...

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(centers=2, random_state=42)

# %%
 import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(TSLA_volume, TSLA_percent_change)
#make_blobs(centers=2, random_state=42)

#print(f"Labels: {y[:10]}")
#print(f"Data: {X[:10]}")
# Out:
# Labels: [0 1 0 1 1 0 1 1 0 0]
# Data: [[-2.98837186  8.82862715]
#  [ 5.72293008  3.02697174]
#  [-3.05358035  9.12520872]
#  [ 5.461939    3.86996267]
#  [ 4.86733877  3.28031244]
#  [-2.14780202 10.55232269]
#  [ 4.91656964  2.80035293]
#  [ 3.08921541  2.04173266]
#  [-2.90130578  7.55077118]
#  [-3.34841515  8.70507375]]

# %%
# Visualizing both classes
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
