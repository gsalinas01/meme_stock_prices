# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Loading data
file_path = "Resources/SPY_stock_hist.csv"
df_SPY_stock_hist = pd.read_csv(file_path)
df_SPY_stock_hist.head(10)
# Out:
#    Unnamed: 0        Date        Open        High         Low       Close  \
# 0           0  2020-11-03  333.690002  338.250000  330.290009  336.029999
# 1           1  2020-11-04  340.859985  347.940002  339.589996  343.540009
# 2           2  2020-11-05  349.239990  352.190002  348.859985  350.239990
# 3           3  2020-11-06  349.929993  351.510010  347.649994  350.160004
# 4           4  2020-11-09  363.970001  364.380005  354.059998  354.559998
# 5           5  2020-11-10  353.489990  355.179993  350.510010  354.040009
# 6           6  2020-11-11  356.399994  357.559998  355.059998  356.670013
# 7           7  2020-11-12  355.579987  356.720001  351.260010  353.209991
# 8           8  2020-11-13  355.269989  358.899994  354.709991  358.100006
# 9           9  2020-11-16  360.980011  362.779999  359.589996  362.570007
#
#     Adj Close     Volume  Percent_Day_Change
# 0  331.362274   93294200            0.701249
# 1  338.767914  126959700            0.786254
# 2  345.374817   82039700            0.286336
# 3  345.295959   74973000            0.065731
# 4  349.634827  172304200           -2.585379
# 5  349.122040   85552000            0.155597
# 6  351.715546   58649000            0.075763
# 7  348.303589   67546200           -0.666516
# 8  353.125671   62892200            0.796582
# 9  357.533600   74541100            0.440466

# %%
# hvplot.scatter plot using x="Volume" and y="Percent_Day_Change".
df_SPY_stock_hist.hvplot.scatter(x='Volume', y='Percent_Day_Change', hover_cols='Open', by='Date')
# Out:
# :NdOverlay   [Date]
#    :Scatter   [Volume]   (Percent_Day_Change,Open)
