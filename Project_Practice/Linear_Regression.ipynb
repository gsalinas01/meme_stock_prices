# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Loading data
file_path = "Resources/TSLA_stock_hist_hourly_2021_11_7.csv"
df_TSLA_stock_hist_hourly_2021_11_7 = pd.read_csv(file_path)
df_TSLA_stock_hist_hourly_2021_11_7.head(10)
# Out:
#                   Unnamed: 0         Open         High          Low  \
# 0  2021-10-28 09:30:00-04:00  1068.305054  1081.000000  1055.209961
# 1  2021-10-28 10:30:00-04:00  1060.180054  1077.464966  1058.890015
# 2  2021-10-28 11:30:00-04:00  1070.839844  1079.689941  1064.349976
# 3  2021-10-28 12:30:00-04:00  1076.949951  1079.649902  1066.000000
# 4  2021-10-28 13:30:00-04:00  1073.250000  1074.030029  1067.589966
# 5  2021-10-28 14:30:00-04:00  1072.770142  1073.249878  1066.109985
# 6  2021-10-28 15:30:00-04:00  1069.753174  1077.760010  1067.500000
# 7  2021-10-29 09:30:00-04:00  1080.000000  1100.000000  1073.204956
# 8  2021-10-29 10:30:00-04:00  1088.750000  1094.880005  1086.599976
# 9  2021-10-29 11:30:00-04:00  1091.359985  1098.000000  1088.599976
#
#          Close    Adj Close   Volume  Percent_Day_Change          date_UTC
# 0  1060.359985  1060.359985  8788599           -0.743708  2021-10-28 05:00
# ...

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
# holds Percent_Day_Change for TSLA hourly
df_TSLA_stock_hist_hourly_2021_11_7 = pd.DataFrame(df_TSLA_stock_hist_hourly_2021_11_7.Percent_Day_Change)
print(df_TSLA_stock_hist_hourly_2021_11_7.shape)
df_TSLA_stock_hist_hourly_2021_11_7.head()
# Out:
# (49, 1)
#    Percent_Day_Change
# 0           -0.743708
# 1            0.949903
# 2            0.517366
# 3           -0.350518
# 4           -0.031676
