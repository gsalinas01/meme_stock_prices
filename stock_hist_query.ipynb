# %%
import time
import datetime
import pandas as pd
# Import package
import yfinance as yf

# %%
#define function to get stock hist data from today to last year

def getstockhist(ticker):
    #set an automated date for today
    today = datetime.date.today()
    year=2000+int(today.strftime("%y"))
    month=int(today.strftime("%m"))
    day=int(today.strftime("%d"))
    
    #set variable for 2 years ago, for start date
    year_start=2000+int(today.strftime("%y"))-2

    #period 1 is the oldest date, period 2 is the newest date
    period1=int(time.mktime(datetime.datetime(year_start,month,day,1,1).timetuple()))
    period2=int(time.mktime(datetime.datetime(year,month,day,1,1).timetuple()))
    # interval is per day 
    interval="1d"
    query_url=f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval={interval}&events=history&includeAdjustedClose=true'
    df=pd.read_csv(query_url)
    df["Percent_Day_Change"]= ((df["Close"]/df["Open"])-1)*100
    # Create the output file (CSV).
    output_data_file = f'resources/{ticker}_stock_hist.csv'
    # Export the City_Data into a CSV.
    df.to_csv(output_data_file)
    return df

# %%
# Get the data for the previous 7 days 
def getstockhist_hourly(ticker):
    
    today = datetime.date.today()
    year=2000+int(today.strftime("%y"))
    month=int(today.strftime("%m"))
    day=int(today.strftime("%d"))
    
    df=yf.download(tickers=ticker, period="7d", interval="1h")
    #create new date_utc columns and % day change
    #stock datetime is in NY time, make it into UTC and round to nearest hour . 
    df["Percent_Day_Change"]= ((df["Close"]/df["Open"])-1)*100
    #df["date_UTC"]=df.index
    #df["date_UTC"]=df["date_UTC"].apply(lambda row: row.datetime.timedelta(minutes=270))
    #df["date_UTC"]=df["date_UTC"].apply(lambda row: row.strftime('%Y-%m-%d %H:%M'))
    #df.reset_index()
    
    output_data_file = f'resources/{ticker}_stock_hist_hourly_{year}_{month}_{day}.csv'
    # Export the City_Data into a CSV.
    df.to_csv(output_data_file)
    return df

# %%
TSLA_hourly_df=getstockhist_hourly("TSLA")
TSLA_hourly_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# 2021-10-28 09:30:00-04:00  1068.305054  1081.000000  1055.209961  1060.359985
# 2021-10-28 10:30:00-04:00  1060.180054  1077.464966  1058.890015  1070.250732
# 2021-10-28 11:30:00-04:00  1070.839844  1079.689941  1064.349976  1076.380005
# 2021-10-28 12:30:00-04:00  1076.949951  1079.649902  1066.000000  1073.175049
# 2021-10-28 13:30:00-04:00  1073.250000  1074.030029  1067.589966  1072.910034
# 2021-10-28 14:30:00-04:00  1072.770142  1073.249878  1066.109985  1069.935059
# 2021-10-28 15:30:00-04:00  1069.753174  1077.760010  1067.500000  1077.089966
# 2021-10-29 09:30:00-04:00  1080.000000  1100.000000  1073.204956  1088.390137
# 2021-10-29 10:30:00-04:00  1088.750000  1094.880005  1086.599976  1091.380005
# 2021-10-29 11:30:00-04:00  1091.359985  1098.000000  1088.599976  1092.359985
# 2021-10-29 12:30:00-04:00  1092.260132  1105.859985  1090.979980  1101.819946
# 2021-10-29 13:30:00-04:00  1101.951294  1103.000000  1094.780029  1096.778198
# 2021-10-29 14:30:00-04:00  1096.685303  1102.000000  1093.000000  1100.569946
# 2021-10-29 15:30:00-04:00  1100.530029  1115.209961  1100.119995  1114.180054
# 2021-11-01 09:30:00-04:00  1145.000000  1150.000000  1118.660034  1135.364990
# 2021-11-01 10:30:00-04:00  1135.300049  1162.364746  1132.560059  1161.375122

# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
TSLA_hist_df=getstockhist("TSLA")

#top 40 rallies 
TSLA_hist_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2019-11-07    65.828003    68.300003    65.603996    67.108002
# 1    2019-11-08    66.900002    67.491997    66.500000    67.428001
# 2    2019-11-11    68.790001    69.837997    68.400002    69.017998
# 3    2019-11-12    69.379997    70.073997    68.807999    69.986000
# 4    2019-11-13    71.000000    71.265999    69.036003    69.222000
# ..          ...          ...          ...          ...          ...
# 499  2021-11-01  1145.000000  1209.750000  1118.660034  1208.589966
# 500  2021-11-02  1159.359985  1208.589966  1146.000000  1172.000000
# 501  2021-11-03  1177.329956  1215.390015  1152.619995  1213.859985
# 502  2021-11-04  1234.410034  1243.489990  1217.000000  1229.910034
# 503  2021-11-05  1228.000000  1239.869995  1208.000000  1222.089966
#
#        Adj Close    Volume  Percent_Day_Change
# 0      67.108002  72336500            1.944460
# 1      67.428001  30346000            0.789236
# 2      69.017998  49933500            0.331439
# 3      69.986000  36797000            0.873455
# 4      69.222000  42100500           -2.504225
# ..           ...       ...                 ...
# 499  1208.589966  56048700            5.553709
# 500  1172.000000  42737800            1.090258
# 501  1213.859985  34628500            3.102786
# 502  1229.910034  25397400           -0.364547
# 503  1222.089966  21579900           -0.481273
#
# [504 rows x 8 columns]

# %%
spy_hist_df=getstockhist("SPY")
spy_hist_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-11-07  308.570007  309.649994  307.660004  308.179993  298.133728
# 1  2019-11-08  307.799988  309.000000  307.029999  308.940002  298.868988
# 2  2019-11-11  307.420013  308.540009  307.269989  308.350006  298.298218
# 3  2019-11-12  308.750000  309.989990  308.149994  309.000000  298.927032
# 4  2019-11-13  307.910004  309.540009  307.660004  309.100006  299.023804
#
#      Volume  Percent_Day_Change
# 0  54272300           -0.126394
# 1  49032100            0.370375
# 2  35797300            0.302515
# 3  46484600            0.080972
# 4  53917700            0.386477

# %%
TSLA_hourly_df["date_UTC"]=TSLA_hourly_df.index
TSLA_hourly_df["date_UTC"]=TSLA_hourly_df.index
TSLA_hourly_df["date_UTC"]=TSLA_hourly_df["date_UTC"].apply(lambda row: row-datetime.timedelta(minutes=270))
TSLA_hourly_df["date_UTC"]=TSLA_hourly_df["date_UTC"].apply(lambda row: row.strftime('%Y-%m-%d %H:%M'))
TSLA_hourly_df.head()
# Out:
#                                   Open         High          Low        Close  \
# 2021-10-28 09:30:00-04:00  1068.305054  1081.000000  1055.209961  1060.359985
# 2021-10-28 10:30:00-04:00  1060.180054  1077.464966  1058.890015  1070.250732
# 2021-10-28 11:30:00-04:00  1070.839844  1079.689941  1064.349976  1076.380005
# 2021-10-28 12:30:00-04:00  1076.949951  1079.649902  1066.000000  1073.175049
# 2021-10-28 13:30:00-04:00  1073.250000  1074.030029  1067.589966  1072.910034
#
#                              Adj Close   Volume  Percent_Day_Change  \
# 2021-10-28 09:30:00-04:00  1060.359985  8788599           -0.743708
# 2021-10-28 10:30:00-04:00  1070.250732  4857422            0.949903
# 2021-10-28 11:30:00-04:00  1076.380005  3591916            0.517366
# 2021-10-28 12:30:00-04:00  1073.175049  3328912           -0.350518
# 2021-10-28 13:30:00-04:00  1072.910034  1543551           -0.031676
#
#                                    date_UTC
# 2021-10-28 09:30:00-04:00  2021-10-28 05:00
# 2021-10-28 10:30:00-04:00  2021-10-28 06:00
# 2021-10-28 11:30:00-04:00  2021-10-28 07:00
# 2021-10-28 12:30:00-04:00  2021-10-28 08:00
# 2021-10-28 13:30:00-04:00  2021-10-28 09:00

# %%
SPY_hourly_df["date_UTC"]=SPY_hourly_df.index
SPY_hourly_df["date_UTC"]=SPY_hourly_df["date_UTC"].apply(lambda row: row-datetime.timedelta(minutes=270))
SPY_hourly_df["date_UTC"]=SPY_hourly_df["date_UTC"].apply(lambda row: row.strftime('%Y-%m-%d %H:%M'))
SPY_hourly_df.head()
# Out:
#                                  Open        High         Low       Close  \
# 2021-10-28 09:30:00-04:00  455.899994  457.125000  455.680115  457.059998
# 2021-10-28 10:30:00-04:00  457.070007  457.976013  457.000000  457.519989
# 2021-10-28 11:30:00-04:00  457.529999  457.950012  456.859985  457.299988
# 2021-10-28 12:30:00-04:00  457.304993  457.429993  456.500000  457.049988
# 2021-10-28 13:30:00-04:00  457.059998  457.869995  457.052490  457.779999
#
#                             Adj Close   Volume  Percent_Day_Change  \
# 2021-10-28 09:30:00-04:00  457.059998  9880982            0.254443
# 2021-10-28 10:30:00-04:00  457.519989  5874814            0.098449
# 2021-10-28 11:30:00-04:00  457.299988  4100046           -0.050272
# 2021-10-28 12:30:00-04:00  457.049988  3684041           -0.055763
# 2021-10-28 13:30:00-04:00  457.779999  7065893            0.157529
#
#                                    date_UTC
# 2021-10-28 09:30:00-04:00  2021-10-28 05:00
# 2021-10-28 10:30:00-04:00  2021-10-28 06:00
# 2021-10-28 11:30:00-04:00  2021-10-28 07:00
# 2021-10-28 12:30:00-04:00  2021-10-28 08:00
# 2021-10-28 13:30:00-04:00  2021-10-28 09:00

# %%
TSLA_hourly_df.to_csv("TSLA_stock_hist_hourly_2021_11_7.csv")
SPY_hourly_df.to_csv("SPY_stock_hist_hourly_2021_11_7.csv")

# %%
tweeter_hour=pd.read_csv("resources\#TSLA_tweet_7days_prior_hist_2021_11_7_perhour.csv")
tweeter_hour["hour"]=tweeter_hour["hour"].astype('timedelta64[h]')
tweeter_hour["day"]=tweeter_hour["day"].astype({'day': 'datetime64[ns]'})
tweeter_hour["date_UTC"]=tweeter_hour["day"]+tweeter_hour["hour"]
tweeter_hour=tweeter_hour.drop(['Unnamed: 0',"hour","day"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-ead2e0005499> in <module>
#       1 tweeter_hour=pd.read_csv("resources\#TSLA_tweet_7days_prior_hist_2021_11_7_perhour.csv")
# ----> 2 tweeter_hour["hour"]=tweeter_hour["hour"].astype('timedelta64[h]')
#       3 tweeter_hour["day"]=tweeter_hour["day"].astype({'day': 'datetime64[ns]'})
#       4 tweeter_hour["date_UTC"]=tweeter_hour["day"]+tweeter_hour["hour"]
#       5 tweeter_hour=tweeter_hour.drop(['Unnamed: 0',"hour","day"], axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'hour'

# %%
tweeter_hour.to_csv("resources\#TSLA_tweet_7days_prior_hist_2021_11_7_perhour.csv")
